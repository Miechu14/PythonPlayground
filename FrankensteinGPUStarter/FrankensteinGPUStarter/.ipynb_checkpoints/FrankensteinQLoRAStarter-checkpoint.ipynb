# %% [markdown]
# ## Setup

# %%
#!pip install -q -U bitsandbytes
#!pip install -q -U transformers
#!pip install -q -U peft
#!pip install -q -U accelerate
#!pip install -q -U datasets
#!pip install -q -U pandas 
#!pip install -q -U torch

# %%
#!pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu126/torch-2.11.0%2Bcu126-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Using cached https://download-r2.pytorch.org/whl/cu126/torchvision-0.26.0%2Bcu126-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: numpy in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from torchvision) (2.2.6)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-12.1.1-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mroze\anaconda3\envs\python310\lib\site-packages (from jinja2->torch) (3.0.2)
# Using cached https://download.pytorch.org/whl/cu126/torch-2.11.0%2Bcu126-cp310-cp310-win_amd64.whl (2596.4 MB)
# Downloading https://download-r2.pytorch.org/whl/cu126/torchvision-0.26.0%2Bcu126-cp310-cp310-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.2 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.2 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.2 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 11.2 MB/s  0:00:00
# Downloading pillow-12.1.1-cp310-cp310-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.0 MB 9.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 10.8 MB/s  0:00:00
# Installing collected packages: pillow, torch, torchvision
#
#    ---------------------------------------- 0/3 [pillow]
#    ---------------------------------------- 0/3 [pillow]
#    ---------------------------------------- 0/3 [pillow]
#    ---------------------------------------- 0/3 [pillow]
#    ---------------------------------------- 0/3 [pillow]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    ---------------------------------------- 3/3 [torchvision]
#
# Successfully installed pillow-12.1.1 torch-2.11.0+cu126 torchvision-0.26.0+cu126

# %%
import random
import torch
import gc
import pandas as pd
from datasets import Dataset
import peft
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
def set_seed(seed=42):
    random.seed(seed)
    torch.manual_seed(seed)

set_seed()
print("All imports successful")
# Out:
# All imports successful

# %%
mistral7b = 'mistralai/Mistral-7B-v0.1'
# STEP 1. Check and make sure you're using the right model and notebook here.
model_name = mistral7b

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv("frankenstein_chunks.csv")
df.head()
# Out:
#                                                 text
# 0  ﻿The Project Gutenberg eBook of Frankenstein; ...
# 1  Further corrections by Menno de Leeuw.\n\n\n**...
# 2  I am already far north of London, and as I wal...
# 3  Its productions and features may be without ex...
# 4  But supposing all these conjectures to be fals...

# %%
print("Dataframe Info:")
print(df.info())
print("\n")
print("Dataframe Description:")
print(df.describe())
print("\n")
print("Number of unique values in each column:")
print(df.nunique())
random_index= random.randint(0, len(df) - 1)
df.loc[random_index, 'text']
# Out:
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    481 non-null    object
# dtypes: object(1)
# memory usage: 3.9+ KB
# None
#
#
# Dataframe Description:
#                                                      text
# count                                                 481
# unique                                                481
# top     International donations are gratefully accepte...
# freq                                                    1
#
#
# Number of unique values in each column:
# text    481
# dtype: int64
# 'The thatch had fallen in, the walls were unplastered, and the\ndoor was off its hinges. I ordered it to be repaired, bought some\nfurniture, and took possession, an incident which would doubtless have\noccasioned some surprise had not all the senses of the cottagers been\nbenumbed by want and squalid poverty. As it was, I lived ungazed at\nand unmolested, hardly thanked for the pittance of food and clothes\nwhich I gave, so much does suffering blunt even the coarsest sensations\nof men.\n\nIn this retreat I devoted the morning to labour; but in the evening,\nwhen the weather permitted, I walked on the stony beach of the sea to\nlisten to the waves as they roared and dashed at my feet. It was a\nmonotonous yet ever-changing scene. I thought of Switzerland; it was\nfar different from this desolate and appalling landscape. '

# %%
df.isnull().sum()
# Out:
# text    0
# dtype: int64

# %%
# Now we'll quickly convert this to a train/test split
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# STEP 2. Convert the train_df and test_df from Pandas into Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df, preserve_index=False)
test_dataset = Dataset.from_pandas(test_df, preserve_index=False)

# %% [markdown]
# ## Model Import and Tokenization

# %%
quant_config = BitsAndBytesConfig(
  # STEP 3. Pass the appropriate parameters here to 4-bit quantize the model, then instantiate the model and check what it's running on.
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype= torch.bfloat16
)
model = AutoModelForCausalLM.from_pretrained(model_name,quantization_config=quant_config)
print("\n\nModel is running on:" + "\n")
model.device
# Out:
# W0331 21:29:58.789000 17728 site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# C:\Users\mroze\anaconda3\envs\python310\lib\site-packages\bitsandbytes\backends\cuda\ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Model is running on:
# device(type='cuda', index=0)

# %%
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model, PeftModel

# STEP 4. Prepare the model for QLoRA. Configure LoRA for our finetuning run. Then tokenize the data.
model = prepare_model_for_kbit_training(model)
config = LoraConfig(
    r=32,
    lora_alpha=64,
    lora_dropout=0.05,
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
tokenized_train_dataset= train_dataset.map(lambda samples: tokenizer(samples["text"],max_length=384,truncation=True),batched=True,remove_columns=train_dataset.column_names)
tokenized_test_dataset = test_dataset.map(lambda samples: tokenizer(samples["text"],max_length=384,truncation=True),batched=True,remove_columns=test_dataset.column_names)
del train_df, test_df
gc.collect()
# Out:
# Map:   0%|          | 0/384 [00:00<?, ? examples/s]
# Map:   0%|          | 0/97 [00:00<?, ? examples/s]
# 125

# %% [markdown]
# ## Base Model Evaluation

# %%
def generate_text(prompt):
  model.eval()
  device = next(model.parameters()).device
  inputs = tokenizer(prompt, return_tensors="pt").to(device)
  with torch.no_grad():
      outputs = model.generate(
          **inputs,
          max_new_tokens=100,
          do_sample = True,
          temperature = 0.7,
          top_p=0.9,
          top_k=50,
          repetition_penalty = 1.1,
          no_repeat_ngram_size=3,
          pad_token_id=tokenizer.eos_token_id,
          eos_token_id=tokenizer.eos_token_id,
          use_cache=True
          )
  output = tokenizer.decode(outputs[0], skip_special_tokens=True)
  return output

# %%
# STEP 5. Generate a completion with the base model for informal evaluation.
base_generation = generate_text("""Write one gothic paragraph in the style of Frankenstein.

I'm afraid I've created a""")
base_generation
# Out:
# C:\Users\mroze\anaconda3\envs\python310\lib\site-packages\bitsandbytes\backends\cuda\ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# "Write one gothic paragraph in the style of Frankenstein.\n\nI'm afraid I've created a monster! It was just supposed to be a quick experiment, but now it's gone mad and is killing innocent people! What have I done?\n\nWhat do you think about this prompt? If you would like to participate in a writing exercise, please leave a comment below!"

# %%
def calc_perplexity(model):
  model.eval()
  device = next(model.parameters()).device  
  total_perplexity = 0
  for row in test_dataset:
    inputs = tokenizer(row['text'], return_tensors="pt", truncation=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    # Calculate the loss without updating the model
    with torch.no_grad():
        outputs = model(**inputs, labels=inputs["input_ids"])
    loss = outputs.loss
    # STEP 6. Complete the equation for perplexity.
    perplexity = torch.exp(loss)
    total_perplexity += perplexity.item()

  num_test_rows = len(test_dataset)
  avg_perplexity = total_perplexity / num_test_rows
  return avg_perplexity

base_ppl = calc_perplexity(model)
base_ppl
# Out:
# 9.116988243515959

# %% [markdown]
# ## Training
#
# Make sure you can leave your browser open for a while. This took about 15 minutes on a Colab T4 GPU.

# %%
import transformers

tokenizer.pad_token = tokenizer.eos_token
model.config.use_cache = False
model.print_trainable_parameters()
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
trainer = transformers.Trainer(
    model=model,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_test_dataset,
    args=transformers.TrainingArguments(
        warmup_steps=2,
        fp16=True,
        logging_steps=10,
        save_steps=100,
        save_total_limit=2,
        eval_strategy="steps",
        eval_steps=100,
        output_dir="outputs",
        per_device_train_batch_size=2,
        gradient_accumulation_steps=8,
        num_train_epochs=1,
        learning_rate=2e-5,
        optim="paged_adamw_8bit",
        report_to="none"
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
)
# STEP 8. Finetune the model.
trainer.train()
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
#adapter_path = "outputs"




#model = PeftModel.from_pretrained(model, adapter_path)
#model.eval()
# Out:
# trainable params: 0 || all params: 7,255,363,584 || trainable%: 0.0000
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 32
#       9 trainer = transformers.Trainer(
#      10     model=model,
#      11     train_dataset=tokenized_train_dataset,
#    (...)
#      29     data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
#      30 )
#      31 # STEP 8. Finetune the model.
# ---> 32 trainer.train()
#      33 gc.collect()
#      34 if torch.cuda.is_available():
#
# File ~\anaconda3\envs\python310\lib\site-packages\transformers\trainer.py:1424, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1422 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1423 with ctx:
# -> 1424     return inner_training_loop(
#    1425         args=args,
#    1426         resume_from_checkpoint=resume_from_checkpoint,
#    1427         trial=trial,
#    1428         ignore_keys_for_eval=ignore_keys_for_eval,
#    1429     )
#
# File ~\anaconda3\envs\python310\lib\site-packages\transformers\trainer.py:1506, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1504 for epoch in range(epochs_trained, num_train_epochs):
#    1505     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1506     self._run_epoch(
#    1507         model=model,
#    1508         epoch=epoch,
#    1509         train_dataloader=train_dataloader,
#    1510         steps_in_epoch=steps_in_epoch,
#    1511         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1512         trial=trial,
#    1513         ignore_keys_for_eval=ignore_keys_for_eval,
#    1514         start_time=start_time,
#    1515         resume_from_checkpoint=resume_from_checkpoint,
#    1516         epochs_trained=epochs_trained,
#    1517         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1518     )
#    1519     if self.control.should_training_stop:
#    1520         break
#
# File ~\anaconda3\envs\python310\lib\site-packages\transformers\trainer.py:1760, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1757 grad_norm = self._get_grad_norm(model, grad_norm=grad_norm)
#    1759 self.control = self.callback_handler.on_pre_optimizer_step(self.args, self.state, self.control)
# -> 1760 self.optimizer.step()
#    1761 self.control = self.callback_handler.on_optimizer_step(self.args, self.state, self.control)
#    1763 # get leaning rate before update
#
# File ~\anaconda3\envs\python310\lib\site-packages\torch\optim\lr_scheduler.py:166, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     164 opt = opt_ref()
#     165 opt._opt_called = True  # type: ignore[union-attr]
# --> 166 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File ~\anaconda3\envs\python310\lib\site-packages\accelerate\optimizer.py:166, in AcceleratedOptimizer.step(self, closure)
#     163 if self.scaler is not None:
#     164     self.optimizer.step = self._optimizer_patched_step_method
# --> 166     self.scaler.step(self.optimizer, closure)
#     167     self.scaler.update()
#     169     if not self._accelerate_step_called:
#     170         # If the optimizer step was skipped, gradient overflow was detected.
#
# File ~\anaconda3\envs\python310\lib\site-packages\torch\amp\grad_scaler.py:476, in GradScaler.step(self, optimizer, *args, **kwargs)
#     473     self.unscale_(optimizer)
#     475 if len(optimizer_state["found_inf_per_device"]) == 0:
# --> 476     raise AssertionError("No inf checks were recorded for this optimizer.")
#     478 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     480 optimizer_state["stage"] = OptState.STEPPED
#
# AssertionError: No inf checks were recorded for this optimizer.

# %% [markdown]
# ## Evaluating the finetuned model

# %%
# STEP 9. Generate a completion with the finetuned model and compare it to the base generation.
ft_generation = generate_text("I'm afraid I've created a ")

print("Base model generation: " + base_generation + "\n\n")
print("Finetuned generation: " + ft_generation)
# Out:
# Base model generation: Write one gothic paragraph in the style of Frankenstein.
#
# I'm afraid I've created a monster! It was just supposed to be a quick experiment, but now it's gone mad and is killing innocent people! What have I done?
#
# What do you think about this prompt? If you would like to participate in a writing exercise, please leave a comment below!
#
#
# Finetuned generation: I'm afraid I've created a 4-year old monster.
#
# For the past 2 years, my son has been in daycare at the local YMCA. He loves it there. Loves. It. There. He's never cried when I drop him off or pick him up. In fact, he'll sometimes cry if we leave without going into the building to say hi to his teachers. When I have to pick him early from school because of an appointment, he asks where his friends are.

# %% [markdown]
# A little more like the original text, right? Try experimenting with the hyperparameters to see if you can improve performance.

# %%
# STEP 10. Calculate the finetuned model's perplexity and compare it to the base model's.
ft_ppl = calc_perplexity(model)
print("Base model perplexity: " + str(base_ppl))
print("Finetuned model perplexity: " + str(ft_ppl))
# Out:
# Base model perplexity: 9.116988243515959
# Finetuned model perplexity: 9.116988243515959
